# %%
import pandas as pd

# %%
rr=pd.read_csv(r"C:\Users\USER\Downloads\sleep_mobile_stress_dataset_15000.csv")
rr
# Out:
#        user_id  age  gender         occupation  daily_screen_time_hours  \
# 0            1   56  Female           Designer                     3.26
# 1            2   46  Female            Teacher                     1.85
# 2            3   32  Female           Designer                     3.04
# 3            4   25    Male  Software Engineer                     9.00
# 4            5   38  Female            Teacher                     3.52
# ...        ...  ...     ...                ...                      ...
# 14995    14996   39    Male            Manager                     8.05
# 14996    14997   22  Female            Student                     6.44
# 14997    14998   51  Female  Software Engineer                     7.01
# 14998    14999   56  Female  Software Engineer                     7.89
# 14999    15000   20  Female         Freelancer                     6.05
#
#        phone_usage_before_sleep_minutes  sleep_duration_hours  \
# ...

# %%
rr.head(10)
# Out:
#    user_id  age  gender         occupation  daily_screen_time_hours  \
# 0        1   56  Female           Designer                     3.26
# 1        2   46  Female            Teacher                     1.85
# 2        3   32  Female           Designer                     3.04
# 3        4   25    Male  Software Engineer                     9.00
# 4        5   38  Female            Teacher                     3.52
# 5        6   56    Male            Teacher                     7.26
# 6        7   36  Female            Teacher                     4.56
# 7        8   40    Male            Manager                     3.36
# 8        9   28    Male            Student                     2.30
# 9       10   28  Female            Manager                     9.75
#
#    phone_usage_before_sleep_minutes  sleep_duration_hours  \
# 0                                86                  5.31
# 1                                32                  7.36
# ...

# %%
rr.tail(10)
# Out:
#        user_id  age  gender         occupation  daily_screen_time_hours  \
# 14990    14991   32  Female         Researcher                     5.40
# 14991    14992   51    Male            Student                     7.75
# 14992    14993   37  Female            Teacher                     5.57
# 14993    14994   54    Male           Designer                     5.58
# 14994    14995   44  Female            Manager                     1.57
# 14995    14996   39    Male            Manager                     8.05
# 14996    14997   22  Female            Student                     6.44
# 14997    14998   51  Female  Software Engineer                     7.01
# 14998    14999   56  Female  Software Engineer                     7.89
# 14999    15000   20  Female         Freelancer                     6.05
#
#        phone_usage_before_sleep_minutes  sleep_duration_hours  \
# 14990                               104                  5.63
# ...

# %%
rr.describe()
# Out:
#             user_id           age  daily_screen_time_hours  \
# count  15000.000000  15000.000000             15000.000000
# mean    7500.500000     38.488467                 5.501528
# std     4330.271354     12.007970                 2.600085
# min        1.000000     18.000000                 1.000000
# 25%     3750.750000     28.000000                 3.260000
# 50%     7500.500000     38.000000                 5.490000
# 75%    11250.250000     49.000000                 7.760000
# max    15000.000000     59.000000                10.000000
#
#        phone_usage_before_sleep_minutes  sleep_duration_hours  \
# count                      15000.000000          15000.000000
# mean                          59.708933              6.509683
# std                           34.641858              1.452689
# min                            0.000000              4.000000
# 25%                           29.000000              5.260000
# ...

# %%
rr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   user_id                           15000 non-null  int64
#  1   age                               15000 non-null  int64
#  2   gender                            15000 non-null  object
#  3   occupation                        15000 non-null  object
#  4   daily_screen_time_hours           15000 non-null  float64
#  5   phone_usage_before_sleep_minutes  15000 non-null  int64
#  6   sleep_duration_hours              15000 non-null  float64
#  7   sleep_quality_score               15000 non-null  float64
#  8   stress_level                      15000 non-null  float64
#  9   caffeine_intake_cups              15000 non-null  int64
#  10  physical_activity_minutes         15000 non-null  int64
# ...

# %%
rr.isnull().sum()
# Out:
# user_id                             0
# age                                 0
# gender                              0
# occupation                          0
# daily_screen_time_hours             0
# phone_usage_before_sleep_minutes    0
# sleep_duration_hours                0
# sleep_quality_score                 0
# stress_level                        0
# caffeine_intake_cups                0
# physical_activity_minutes           0
# notifications_received_per_day      0
# mental_fatigue_score                0
# dtype: int64

# %%
rr['daily_screen_time_hours'].max()
# Out:
# 10.0

# %%
rr['age'].max()
# Out:
# 59

# %%
rr['age'].min()
# Out:
# 18

# %%
rr.sort_values(by='daily_screen_time_hours',ascending=False)
# Out:
#        user_id  age  gender         occupation  daily_screen_time_hours  \
# 14169    14170   59    Male         Researcher                     10.0
# 13995    13996   35  Female  Software Engineer                     10.0
# 919        920   26    Male             Doctor                     10.0
# 2327      2328   38  Female            Manager                     10.0
# 10101    10102   37  Female           Designer                     10.0
# ...        ...  ...     ...                ...                      ...
# 1999      2000   24    Male            Student                      1.0
# 1567      1568   52    Male             Doctor                      1.0
# 5403      5404   49    Male            Student                      1.0
# 7779      7780   39  Female         Freelancer                      1.0
# 9758      9759   43    Male             Doctor                      1.0
#
#        phone_usage_before_sleep_minutes  sleep_duration_hours  \
# ...

# %%
rr.sort_values(by='daily_screen_time_hours',ascending=True)
# Out:
#        user_id  age  gender         occupation  daily_screen_time_hours  \
# 8179      8180   36    Male            Manager                      1.0
# 1567      1568   52    Male             Doctor                      1.0
# 5403      5404   49    Male            Student                      1.0
# 1999      2000   24    Male            Student                      1.0
# 7779      7780   39  Female         Freelancer                      1.0
# ...        ...  ...     ...                ...                      ...
# 10101    10102   37  Female           Designer                     10.0
# 919        920   26    Male             Doctor                     10.0
# 2327      2328   38  Female            Manager                     10.0
# 13995    13996   35  Female  Software Engineer                     10.0
# 14169    14170   59    Male         Researcher                     10.0
#
#        phone_usage_before_sleep_minutes  sleep_duration_hours  \
# ...

# %%
rr.sort_values(by='sleep_duration_hours',ascending=False).head(10)
# Out:
#        user_id  age  gender         occupation  daily_screen_time_hours  \
# 4210      4211   49    Male           Designer                     2.70
# 914        915   47  Female            Student                     2.80
# 10142    10143   25  Female           Designer                     8.68
# 8170      8171   57    Male         Freelancer                     1.11
# 12306    12307   34  Female           Designer                     4.69
# 8743      8744   34  Female         Freelancer                     7.32
# 9277      9278   21   Other  Software Engineer                     1.48
# 867        868   23  Female           Designer                     4.05
# 8462      8463   18    Male            Teacher                     7.61
# 4071      4072   36  Female            Student                     9.33
#
#        phone_usage_before_sleep_minutes  sleep_duration_hours  \
# 4210                                 30                  9.00
# ...

# %%
rr.sort_values(by='sleep_duration_hours',ascending=True).head(10)
# Out:
#        user_id  age  gender  occupation  daily_screen_time_hours  \
# 4136      4137   20    Male    Designer                     1.04
# 10768    10769   36  Female  Freelancer                     4.43
# 10801    10802   22  Female     Student                     2.99
# 5467      5468   43    Male    Designer                     3.49
# 14164    14165   49    Male  Freelancer                     3.82
# 10240    10241   22    Male     Student                     7.92
# 4659      4660   26  Female     Student                     1.69
# 1684      1685   59    Male     Manager                     3.35
# 14464    14465   44  Female    Designer                     3.64
# 7101      7102   41    Male  Freelancer                     4.69
#
#        phone_usage_before_sleep_minutes  sleep_duration_hours  \
# 4136                                 29                   4.0
# 10768                                75                   4.0
# ...

# %%
rr.sort_values(by='stress_level',ascending=False).head(10)
# Out:
#       user_id  age  gender         occupation  daily_screen_time_hours  \
# 7500     7501   22  Female           Designer                     9.48
# 8483     8484   45  Female           Designer                     8.23
# 8530     8531   56    Male         Researcher                     6.10
# 8528     8529   43  Female            Teacher                     7.89
# 8526     8527   41    Male         Researcher                     8.13
# 8524     8525   58    Male            Manager                     7.91
# 8523     8524   19    Male            Student                     7.23
# 8521     8522   30   Other  Software Engineer                     8.93
# 3005     3006   55    Male            Student                     6.15
# 8516     8517   38    Male           Designer                     9.50
#
#       phone_usage_before_sleep_minutes  sleep_duration_hours  \
# 7500                                25                  6.24
# 8483                                68                  7.54
# ...

# %%
rr.sort_values(by='stress_level',ascending=True).head(10)
# Out:
#        user_id  age  gender         occupation  daily_screen_time_hours  \
# 6465      6466   32    Male            Teacher                     1.21
# 3427      3428   36  Female         Freelancer                     1.67
# 9481      9482   56    Male            Manager                     1.69
# 3426      3427   30    Male         Researcher                     1.15
# 12099    12100   45  Female         Freelancer                     1.92
# 6510      6511   43  Female             Doctor                     1.22
# 6514      6515   28    Male            Student                     1.23
# 12110    12111   48  Female            Teacher                     1.92
# 9424      9425   52    Male  Software Engineer                     1.44
# 3408      3409   40  Female  Software Engineer                     2.87
#
#        phone_usage_before_sleep_minutes  sleep_duration_hours  \
# 6465                                 58                  6.90
# ...

# %%
len(rr[(rr['age'] < 40) & (rr['daily_screen_time_hours'] > 7)])
# Out:
# 2601

# %%
len(rr[(rr['age'] > 40) & (rr['daily_screen_time_hours'] > 7)])
# Out:
# 2230

# %%
len(rr[(rr['age'] > 40) & (rr['stress_level'] > 6)])
# Out:
# 4263

# %%
len(rr[(rr['age'] < 40) & (rr['stress_level'] > 6)])
# Out:
# 4972

# %%
rr.groupby('occupation')['daily_screen_time_hours'].count()
# Out:
# occupation
# Designer             1813
# Doctor               1922
# Freelancer           1891
# Manager              1962
# Researcher           1837
# Software Engineer    1917
# Student              1861
# Teacher              1797
# Name: daily_screen_time_hours, dtype: int64

# %%
rr.groupby('occupation')['daily_screen_time_hours'].sum()
# Out:
# occupation
# Designer              9883.85
# Doctor               10556.80
# Freelancer           10229.31
# Manager              10875.39
# Researcher           10021.27
# Software Engineer    10640.12
# Student              10486.68
# Teacher               9829.50
# Name: daily_screen_time_hours, dtype: float64

# %%
rr.groupby('gender')['daily_screen_time_hours'].sum()
# Out:
# gender
# Female    39403.28
# Male      39845.07
# Other      3274.57
# Name: daily_screen_time_hours, dtype: float64

# %%
rr.groupby('gender')['stress_level'].sum()
# Out:
# gender
# Female    49913.15
# Male      50636.67
# Other      4153.88
# Name: stress_level, dtype: float64

# %%
rr.groupby('gender')['mental_fatigue_score'].sum()
# Out:
# gender
# Female    49200.76
# Male      49864.45
# Other      4029.92
# Name: mental_fatigue_score, dtype: float64

# %%
rr.groupby('gender')['physical_activity_minutes'].sum()
# Out:
# gender
# Female    422873
# Male      428856
# Other      35628
# Name: physical_activity_minutes, dtype: int64

# %%
rr.groupby('occupation')['caffeine_intake_cups'].sum()
# Out:
# occupation
# Designer             3566
# Doctor               3875
# Freelancer           3886
# Manager              3939
# Researcher           3708
# Software Engineer    3754
# Student              3743
# Teacher              3511
# Name: caffeine_intake_cups, dtype: int64

# %%
rr.groupby('age')['stress_level'].mean()
# Out:
# age
# 18    7.045266
# 19    6.867667
# 20    6.744543
# 21    7.082817
# 22    7.075089
# 23    6.948832
# 24    7.116707
# 25    7.089008
# 26    6.833391
# 27    7.234191
# 28    7.004199
# 29    6.763362
# 30    7.033611
# 31    6.884262
# 32    6.814468
# 33    6.822048
# 34    7.041030
# 35    7.174447
# 36    6.906332
# 37    7.099086
# 38    6.886260
# 39    6.869013
# 40    6.979922
# 41    6.735531
# 42    7.153040
# 43    7.187345
# 44    7.051687
# 45    6.910649
# 46    7.033443
# 47    6.963084
# 48    6.916409
# 49    6.992697
# 50    7.118977
# 51    7.052130
# 52    6.924901
# 53    6.680741
# 54    6.864767
# 55    7.129217
# 56    7.178681
# 57    7.050378
# 58    6.997824
# 59    6.929331
# Name: stress_level, dtype: float64

# %%
rr.pivot_table(index='gender',columns='occupation',values='sleep_quality_score',aggfunc='mean')
# Out:
# occupation  Designer    Doctor  Freelancer   Manager  Researcher  \
# gender
# Female      6.297439  6.258025    6.315797  6.214964    6.289053
# Male        6.341359  6.270889    6.231161  6.196580    6.295119
# Other       6.468451  5.986290    6.361806  6.390260    6.336250
#
# occupation  Software Engineer   Student   Teacher
# gender
# Female               6.247797  6.144879  6.386843
# Male                 6.152577  6.092975  6.199285
# Other                6.267356  5.925974  6.423390

# %%
rr.pivot_table(index='gender',columns='occupation',values='mental_fatigue_score',aggfunc='mean')
# Out:
# occupation  Designer    Doctor  Freelancer   Manager  Researcher  \
# gender
# Female      6.753900  6.864801    6.800167  6.999053    6.820605
# Male        6.732480  6.854842    6.834707  6.947879    6.796436
# Other       6.807606  7.272419    6.620139  6.788312    6.715000
#
# occupation  Software Engineer   Student   Teacher
# gender
# Female               6.869503  6.998934  6.682423
# Male                 6.974635  7.059279  6.949020
# Other                6.896207  7.359610  6.652203

# %%
rr.pivot_table(index='gender',columns='occupation',values='sleep_duration_hours',aggfunc='mean')
# Out:
# occupation  Designer    Doctor  Freelancer   Manager  Researcher  \
# gender
# Female      6.527683  6.391839    6.479911  6.489095    6.552877
# Male        6.554700  6.489765    6.494837  6.535595    6.448127
# Other       6.574507  6.518387    6.678056  6.753117    6.530000
#
# occupation  Software Engineer   Student   Teacher
# gender
# Female               6.539276  6.572495  6.483605
# Male                 6.460332  6.493227  6.597855
# Other                6.609080  6.527013  6.405085
